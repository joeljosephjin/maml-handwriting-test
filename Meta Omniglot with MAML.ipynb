# %%
import random
import numpy as np
import torch
import learn2learn as l2l

from torch import nn, optim

# %%
def accuracy(predictions, targets):
    predictions = predictions.argmax(dim=1).view(targets.shape)
    return (predictions == targets).sum().float() / targets.size(0)


def fast_adapt(batch, learner, loss, adaptation_steps, shots, ways, device):
    data, labels = batch
    data, labels = data.to(device), labels.to(device)

    # Separate data into adaptation/evalutation sets
    adaptation_indices = np.zeros(data.size(0), dtype=bool)
    adaptation_indices[np.arange(shots*ways) * 2] = True
    evaluation_indices = torch.from_numpy(~adaptation_indices)
    adaptation_indices = torch.from_numpy(adaptation_indices)
    adaptation_data, adaptation_labels = data[adaptation_indices], labels[adaptation_indices]
    evaluation_data, evaluation_labels = data[evaluation_indices], labels[evaluation_indices]

    # Adapt the model
    for step in range(adaptation_steps):
        train_error = loss(learner(adaptation_data), adaptation_labels)
        learner.adapt(train_error)

    # Evaluate the adapted model
    predictions = learner(evaluation_data)
    valid_error = loss(predictions, evaluation_labels)
    valid_accuracy = accuracy(predictions, evaluation_labels)
    return valid_error, valid_accuracy

# %%
ways=5
shots=5
meta_lr=0.003
fast_lr=0.5
meta_batch_size=32
adaptation_steps=1
num_iterations=6000 # 60000
cuda=False
seed=42

# %%
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
device = torch.device('cpu')
if cuda:
    torch.cuda.manual_seed(seed)
    device = torch.device('cuda')

# Load train/validation/test tasksets using the benchmark interface
tasksets = l2l.vision.benchmarks.get_tasksets('omniglot',
                                              train_ways=ways,
                                              train_samples=2*shots,
                                              test_ways=ways,
                                              test_samples=2*shots,
                                              num_tasks=20000,
                                              root='~/data',
)

# Create model
model = l2l.vision.models.OmniglotFC(28 ** 2, ways)
model.to(device)
maml = l2l.algorithms.MAML(model, lr=fast_lr, first_order=False)
opt = optim.Adam(maml.parameters(), meta_lr)
loss = nn.CrossEntropyLoss(reduction='mean')

for iteration in range(num_iterations):
    opt.zero_grad()
    meta_train_error = 0.0
    meta_train_accuracy = 0.0
    meta_valid_error = 0.0
    meta_valid_accuracy = 0.0
    for task in range(meta_batch_size):
        # Compute meta-training loss
        learner = maml.clone()
        batch = tasksets.train.sample()
        evaluation_error, evaluation_accuracy = fast_adapt(batch,
                                                           learner,
                                                           loss,
                                                           adaptation_steps,
                                                           shots,
                                                           ways,
                                                           device)
        evaluation_error.backward()
        meta_train_error += evaluation_error.item()
        meta_train_accuracy += evaluation_accuracy.item()

        # Compute meta-validation loss
        learner = maml.clone()
        batch = tasksets.validation.sample()
        evaluation_error, evaluation_accuracy = fast_adapt(batch,
                                                           learner,
                                                           loss,
                                                           adaptation_steps,
                                                           shots,
                                                           ways,
                                                           device)
        meta_valid_error += evaluation_error.item()
        meta_valid_accuracy += evaluation_accuracy.item()

    # Print some metrics
    print('\n')
    print('Iteration', iteration)
    print('Meta Train Error', meta_train_error / meta_batch_size)
    print('Meta Train Accuracy', meta_train_accuracy / meta_batch_size)
    print('Meta Valid Error', meta_valid_error / meta_batch_size)
    print('Meta Valid Accuracy', meta_valid_accuracy / meta_batch_size)

    # Average the accumulated gradients and optimize
    for p in maml.parameters():
        p.grad.data.mul_(1.0 / meta_batch_size)
    opt.step()

meta_test_error = 0.0
meta_test_accuracy = 0.0
for task in range(meta_batch_size):
    # Compute meta-testing loss
    learner = maml.clone()
    batch = tasksets.test.sample()
    evaluation_error, evaluation_accuracy = fast_adapt(batch,
                                                       learner,
                                                       loss,
                                                       adaptation_steps,
                                                       shots,
                                                       ways,
                                                       device)
    meta_test_error += evaluation_error.item()
    meta_test_accuracy += evaluation_accuracy.item()
print('Meta Test Error', meta_test_error / meta_batch_size)
print('Meta Test Accuracy', meta_test_accuracy / meta_batch_size)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# /home/elian/miniconda3/lib/python3.8/site-packages/torch/autograd/__init__.py:202: UserWarning: CUDA initialization: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx (Triggered internally at  /pytorch/c10/cuda/CUDAFunctions.cpp:100.)
#   return Variable._execution_engine.run_backward(
# Iteration 0
# Meta Train Error 1.536802627146244
# Meta Train Accuracy 0.3575000006239861
# Meta Valid Error 1.5398506298661232
# Meta Valid Accuracy 0.32874999660998583
#
#
# Iteration 1
# Meta Train Error 1.4320994541049004
# Meta Train Accuracy 0.43374999705702066
# Meta Valid Error 1.4276456125080585
# Meta Valid Accuracy 0.46625000098720193
#
#
# Iteration 2
# Meta Train Error 1.27377974614501
# Meta Train Accuracy 0.5412499979138374
# Meta Valid Error 1.2977323308587074
# Meta Valid Accuracy 0.5150000043213367
#
#
# Iteration 3
# Meta Train Error 1.2362913750112057
# Meta Train Accuracy 0.4824999966658652
# Meta Valid Error 1.222744420170784
# Meta Valid Accuracy 0.4974999953992665
#
#
# Iteration 4
# Meta Train Error 1.1136803310364485
# Meta Train Accuracy 0.566249999217689
# Meta Valid Error 1.1581104155629873
# Meta Valid Accuracy 0.5525000002235174
#
#
# Iteration 5
# Meta Train Error 1.05033278465271
# Meta Train Accuracy 0.5875000050291419
# Meta Valid Error 1.1074686236679554
# Meta Valid Accuracy 0.5574999982491136
#
#
# Iteration 6
# Meta Train Error 0.9493422545492649
# Meta Train Accuracy 0.65750000346452
# Meta Valid Error 1.0278329718858004
# Meta Valid Accuracy 0.6224999967962503
#
#
# Iteration 7
# Meta Train Error 0.9795522633939981
# Meta Train Accuracy 0.6512499991804361
# Meta Valid Error 0.9739472549408674
# Meta Valid Accuracy 0.6187500022351742
#
#
# Iteration 8
# Meta Train Error 0.9518471285700798
# Meta Train Accuracy 0.6512500019744039
# Meta Valid Error 0.9802623223513365
# Meta Valid Accuracy 0.6437500016763806
#
#
# Iteration 9
# Meta Train Error 0.9507213700562716
# Meta Train Accuracy 0.6412500021979213
# Meta Valid Error 0.9795691482722759
# Meta Valid Accuracy 0.6112500000745058
#
#
# Iteration 10
# Meta Train Error 0.8934178370982409
# Meta Train Accuracy 0.6875000046566129
# Meta Valid Error 0.9800877869129181
# Meta Valid Accuracy 0.6400000043213367
#
#
# Iteration 11
# Meta Train Error 0.8594577834010124
# Meta Train Accuracy 0.693749999627471
# Meta Valid Error 0.9356165416538715
# Meta Valid Accuracy 0.6525000026449561
#
#
# Iteration 12
# Meta Train Error 0.83266163431108
# Meta Train Accuracy 0.7124999985098839
# Meta Valid Error 0.9080786537379026
# Meta Valid Accuracy 0.6687500048428774
#
#
# Iteration 13
# Meta Train Error 0.8176304819062352
# Meta Train Accuracy 0.7250000042840838
# Meta Valid Error 0.8826613575220108
# Meta Valid Accuracy 0.6725000040605664
#
#
# Iteration 14
# Meta Train Error 0.8411017656326294
# Meta Train Accuracy 0.7050000010058284
# Meta Valid Error 0.9088157955557108
# Meta Valid Accuracy 0.6712500005960464
#
#
# Iteration 15
# Meta Train Error 0.7842504354193807
# Meta Train Accuracy 0.7262500002980232
# Meta Valid Error 0.8194274101406336
# Meta Valid Accuracy 0.6887500025331974
#
#
# Iteration 16
# Meta Train Error 0.8187313862144947
# Meta Train Accuracy 0.7162500023841858
# Meta Valid Error 0.8930843975394964
# Meta Valid Accuracy 0.6675000032410026
#
#
# Iteration 17
# Meta Train Error 0.7930839490145445
# Meta Train Accuracy 0.7174999993294477
# Meta Valid Error 0.7437556209042668
# Meta Valid Accuracy 0.7324999999254942
#
#
# Iteration 18
# Meta Train Error 0.804570727981627
# Meta Train Accuracy 0.7275000046938658
# Meta Valid Error 0.828863512724638
# Meta Valid Accuracy 0.696250001899898
#
#
# Iteration 19
# Meta Train Error 0.7454411592334509
# Meta Train Accuracy 0.7362500000745058
# Meta Valid Error 0.8208614746108651
# Meta Valid Accuracy 0.6862499993294477
#
#
# Iteration 20
# Meta Train Error 0.7356005012989044
# Meta Train Accuracy 0.7300000013783574
# Meta Valid Error 0.8024056358262897
# Meta Valid Accuracy 0.7000000020489097
#
#
# Iteration 21
# Meta Train Error 0.7576975794509053
# Meta Train Accuracy 0.7287500016391277
# Meta Valid Error 0.7940879408270121
# Meta Valid Accuracy 0.7200000025331974
#
#
# Iteration 22
# Meta Train Error 0.7216340508311987
# Meta Train Accuracy 0.7474999949336052
# Meta Valid Error 0.7967393863946199
# Meta Valid Accuracy 0.7062500044703484
#
#
# Iteration 23
# Meta Train Error 0.7537748152390122
# Meta Train Accuracy 0.7312499992549419
# Meta Valid Error 0.7935224296525121
# Meta Valid Accuracy 0.7225000001490116
#
#
# Iteration 24
# Meta Train Error 0.7760452711954713
# Meta Train Accuracy 0.717500003054738
# Meta Valid Error 0.7345020519569516
# Meta Valid Accuracy 0.7325000017881393
#
#
# Iteration 25
# Meta Train Error 0.689824977889657
# Meta Train Accuracy 0.7375000035390258
# Meta Valid Error 0.8194290399551392
# Meta Valid Accuracy 0.69875000230968
#
#
# Iteration 26
# Meta Train Error 0.7244619093835354
# Meta Train Accuracy 0.7250000028871
# Meta Valid Error 0.7558110915124416
# Meta Valid Accuracy 0.75
#
#
# Iteration 27
# Meta Train Error 0.7459573792293668
# Meta Train Accuracy 0.7387499986216426
# Meta Valid Error 0.7220038287341595
# Meta Valid Accuracy 0.7250000033527613
#
#
# Iteration 28
# Meta Train Error 0.6374771445989609
# Meta Train Accuracy 0.7887499975040555
# Meta Valid Error 0.712312925606966
# Meta Valid Accuracy 0.7375000016763806
#
#
# Iteration 29
# Meta Train Error 0.6625002576038241
# Meta Train Accuracy 0.7687500016763806
# Meta Valid Error 0.7264602347277105
# Meta Valid Accuracy 0.7300000004470348
#
#
# Iteration 30
# Meta Train Error 0.6515953829512
# Meta Train Accuracy 0.7625000020489097
# Meta Valid Error 0.6593307955190539
# Meta Valid Accuracy 0.7675000000745058
#
#
# Iteration 31
# Meta Train Error 0.6748025389388204
# Meta Train Accuracy 0.7575000002980232
# Meta Valid Error 0.6572626335546374
# Meta Valid Accuracy 0.7662500068545341
#
#
# Iteration 32
# Meta Train Error 0.6709375530481339
# Meta Train Accuracy 0.7562500042840838
# Meta Valid Error 0.7349703954532743
# Meta Valid Accuracy 0.7300000004470348
#
#
# Iteration 33
# Meta Train Error 0.662759643048048
# Meta Train Accuracy 0.766249998472631
# Meta Valid Error 0.619171199388802
# Meta Valid Accuracy 0.7900000009685755
#
#
# Iteration 34
# Meta Train Error 0.6357794525101781
# Meta Train Accuracy 0.7924999976530671
# Meta Valid Error 0.7155964309349656
# Meta Valid Accuracy 0.7437500050291419
#
#
# Iteration 35
# Meta Train Error 0.6318779680877924
# Meta Train Accuracy 0.7750000059604645
# Meta Valid Error 0.704265178181231
# Meta Valid Accuracy 0.7400000030174851
#
#
# Iteration 36
# Meta Train Error 0.5614297986030579
# Meta Train Accuracy 0.8237499967217445
# Meta Valid Error 0.7127276547253132
# Meta Valid Accuracy 0.7524999994784594
#
#
# Iteration 37
# Meta Train Error 0.6041766288690269
# Meta Train Accuracy 0.7937499955296516
# Meta Valid Error 0.7827040953561664
# Meta Valid Accuracy 0.7137500056996942
#
#
# Iteration 38
# Meta Train Error 0.5790888769552112
# Meta Train Accuracy 0.8174999952316284
# Meta Valid Error 0.6651871223002672
# Meta Valid Accuracy 0.7524999976158142
#
#
# Iteration 39
# Meta Train Error 0.6311780116520822
# Meta Train Accuracy 0.7787499986588955
# Meta Valid Error 0.6872648801654577
# Meta Valid Accuracy 0.7575000002980232
#
#
# Iteration 40
# Meta Train Error 0.5881287660449743
# Meta Train Accuracy 0.8099999986588955
# Meta Valid Error 0.6681538997218013
# Meta Valid Accuracy 0.7512500043958426
#
#
# Iteration 41
# Meta Train Error 0.5684222741983831
# Meta Train Accuracy 0.8012499958276749
# Meta Valid Error 0.6128301657736301
# Meta Valid Accuracy 0.7712500039488077
#
#
# Iteration 42
# Meta Train Error 0.630053773522377
# Meta Train Accuracy 0.77125000115484
# Meta Valid Error 0.693062074482441
# Meta Valid Accuracy 0.7412500018253922
#
#
# Iteration 43
# Meta Train Error 0.570915742777288
# Meta Train Accuracy 0.8075000029057264
# Meta Valid Error 0.6319701923057437
# Meta Valid Accuracy 0.7724999990314245
#
#
# Iteration 44
# Meta Train Error 0.6252469676546752
# Meta Train Accuracy 0.7875000024214387
# Meta Valid Error 0.5878826584666967
# Meta Valid Accuracy 0.7962499987334013
#
#
# Iteration 45
# Meta Train Error 0.5514176217839122
# Meta Train Accuracy 0.8187500014901161
# Meta Valid Error 0.5915771396830678
# Meta Valid Accuracy 0.7987499963492155
#
#
# Iteration 46
# Meta Train Error 0.5685920552350581
# Meta Train Accuracy 0.7762500047683716
# Meta Valid Error 0.5704519171267748
# Meta Valid Accuracy 0.7837499957531691
#
#
# Iteration 47
# Meta Train Error 0.5781546346843243
# Meta Train Accuracy 0.806250000372529
# Meta Valid Error 0.6338577726855874
# Meta Valid Accuracy 0.7837500050663948
#
#
# Iteration 48
# Meta Train Error 0.6120168319903314
# Meta Train Accuracy 0.787499999627471
# Meta Valid Error 0.6930905664339662
# Meta Valid Accuracy 0.737499997485429
#
#
# Iteration 49
# Meta Train Error 0.5143454656936228
# Meta Train Accuracy 0.8274999931454659
# Meta Valid Error 0.5867176307365298
# Meta Valid Accuracy 0.78999999538064
#
#
# Iteration 50
# Meta Train Error 0.6053553111851215
# Meta Train Accuracy 0.7924999967217445
# Meta Valid Error 0.595995718613267
# Meta Valid Accuracy 0.787499999627471
# Iteration 51
# Meta Train Error 0.6029725852422416
# Meta Train Accuracy 0.7862499980255961
# Meta Valid Error 0.6270178821869195
# Meta Valid Accuracy 0.76999999769032
#
#
# Iteration 52
# Meta Train Error 0.5638855006545782
# Meta Train Accuracy 0.7975000031292439
# Meta Valid Error 0.5920722875744104
# Meta Valid Accuracy 0.8049999941140413
#
#
# Iteration 53
# Meta Train Error 0.6192152760922909
# Meta Train Accuracy 0.7637500008568168
# Meta Valid Error 0.6239639734849334
# Meta Valid Accuracy 0.7699999986216426
#
#
# Iteration 54
# Meta Train Error 0.5474966447800398
# Meta Train Accuracy 0.8124999981373549
# Meta Valid Error 0.673550701700151
# Meta Valid Accuracy 0.7500000027939677
#
#
# Iteration 55
# Meta Train Error 0.5796393433120102
# Meta Train Accuracy 0.7974999938160181
# Meta Valid Error 0.6460838518105447
# Meta Valid Accuracy 0.7824999997392297
#
#
# Iteration 56
# Meta Train Error 0.5222367318347096
# Meta Train Accuracy 0.8174999970942736
# Meta Valid Error 0.6239109169691801
# Meta Valid Accuracy 0.7787499967962503
#
#
# Iteration 57
# Meta Train Error 0.5346636581234634
# Meta Train Accuracy 0.788750003091991
# Meta Valid Error 0.6017095716670156
# Meta Valid Accuracy 0.7874999977648258
#
#
# Iteration 58
# Meta Train Error 0.5277900956571102
# Meta Train Accuracy 0.8175000008195639
# Meta Valid Error 0.5852993139997125
# Meta Valid Accuracy 0.7900000009685755
#
#
# Iteration 59
# Meta Train Error 0.5897721406072378
# Meta Train Accuracy 0.7687500091269612
# Meta Valid Error 0.6435516737401485
# Meta Valid Accuracy 0.7512500043958426
#
#
# Iteration 60
# Meta Train Error 0.5182553855702281
# Meta Train Accuracy 0.8162499964237213
# Meta Valid Error 0.6341893528588116
# Meta Valid Accuracy 0.7812499981373549
#
#
# Iteration 61
# Meta Train Error 0.5691505284048617
# Meta Train Accuracy 0.7937499992549419
# Meta Valid Error 0.5768878324888647
# Meta Valid Accuracy 0.7962499987334013
#
#
# Iteration 62
# Meta Train Error 0.49790965393185616
# Meta Train Accuracy 0.8399999979883432
# Meta Valid Error 0.6791621074080467
# Meta Valid Accuracy 0.7487500002607703
#
#
# Iteration 63
# Meta Train Error 0.4949420038610697
# Meta Train Accuracy 0.8187500014901161
# Meta Valid Error 0.6016163425520062
# Meta Valid Accuracy 0.7824999988079071
#
#
# Iteration 64
# Meta Train Error 0.54049541358836
# Meta Train Accuracy 0.8099999986588955
# Meta Valid Error 0.5425102584995329
# Meta Valid Accuracy 0.7912499979138374
#
#
# Iteration 65
# Meta Train Error 0.4894852959550917
# Meta Train Accuracy 0.8262500017881393
# Meta Valid Error 0.6026165494695306
# Meta Valid Accuracy 0.7750000040978193
#
#
# Iteration 66
# Meta Train Error 0.5046686134301126
# Meta Train Accuracy 0.8212499935179949
# Meta Valid Error 0.6113921087235212
# Meta Valid Accuracy 0.7575000012293458
#
#
# Iteration 67
# Meta Train Error 0.5199858201667666
# Meta Train Accuracy 0.8212500009685755
# Meta Valid Error 0.5479716621339321
# Meta Valid Accuracy 0.8024999964982271
#
#
# Iteration 68
# Meta Train Error 0.5008583385497332
# Meta Train Accuracy 0.8199999965727329
# Meta Valid Error 0.5310132740996778
# Meta Valid Accuracy 0.8024999983608723
#
#
# Iteration 69
# Meta Train Error 0.5411350065842271
# Meta Train Accuracy 0.7887499956414104
# Meta Valid Error 0.6688592461869121
# Meta Valid Accuracy 0.743750000372529
#
#
# Iteration 70
# Meta Train Error 0.46426975494250655
# Meta Train Accuracy 0.83249999769032
# Meta Valid Error 0.5633117738179862
# Meta Valid Accuracy 0.8200000002980232
#
#
# Iteration 71
# Meta Train Error 0.46833007829263806
# Meta Train Accuracy 0.8337499927729368
# Meta Valid Error 0.5915491837076843
# Meta Valid Accuracy 0.7800000021234155
#
#
# Iteration 72
# Meta Train Error 0.45526622724719346
# Meta Train Accuracy 0.8424999974668026
# Meta Valid Error 0.540261137066409
# Meta Valid Accuracy 0.8050000015646219
#
#
# Iteration 73
# Meta Train Error 0.5351053476333618
# Meta Train Accuracy 0.7962499931454659
# Meta Valid Error 0.585620578378439
# Meta Valid Accuracy 0.7787499958649278
#
#
# Iteration 74
# Meta Train Error 0.5288006411865354
# Meta Train Accuracy 0.8162499982863665
# Meta Valid Error 0.5829414231702685
# Meta Valid Accuracy 0.7874999959021807
#
#
# Iteration 75
# Meta Train Error 0.43042022408917546
# Meta Train Accuracy 0.8637500051409006
# Meta Valid Error 0.5937647859100252
# Meta Valid Accuracy 0.7774999979883432
#
#
# Iteration 76
# Meta Train Error 0.5220155655406415
# Meta Train Accuracy 0.7849999982863665
# Meta Valid Error 0.6215112749487162
# Meta Valid Accuracy 0.7525000022724271
#
#
# Iteration 77
# Meta Train Error 0.42424284340813756
# Meta Train Accuracy 0.8649999983608723
# Meta Valid Error 0.5341506181284785
# Meta Valid Accuracy 0.8137499988079071
#
#
# Iteration 78
# Meta Train Error 0.5060251490212977
# Meta Train Accuracy 0.8174999989569187
# Meta Valid Error 0.6657966310158372
# Meta Valid Accuracy 0.7575000002980232
#
#
# Iteration 79
# Meta Train Error 0.4691704532597214
# Meta Train Accuracy 0.8424999974668026
# Meta Valid Error 0.5230577234178782
# Meta Valid Accuracy 0.8249999992549419
#
#
# Iteration 80
# Meta Train Error 0.5082494658418
# Meta Train Accuracy 0.8237499948590994
# Meta Valid Error 0.5703879557549953
# Meta Valid Accuracy 0.7749999994412065
#
#
# Iteration 81
# Meta Train Error 0.39432542445138097
# Meta Train Accuracy 0.8737499993294477
# Meta Valid Error 0.5116323218680918
# Meta Valid Accuracy 0.8125
#
#
# Iteration 82
# Meta Train Error 0.4039720550645143
# Meta Train Accuracy 0.8612499982118607
# Meta Valid Error 0.5793314129114151
# Meta Valid Accuracy 0.7800000049173832
#
#
# Iteration 83
# Meta Train Error 0.44270507991313934
# Meta Train Accuracy 0.8487499952316284
# Meta Valid Error 0.4980384283699095
# Meta Valid Accuracy 0.8149999920278788
#
#
# Iteration 84
# Meta Train Error 0.481702936347574
# Meta Train Accuracy 0.8349999971687794
# Meta Valid Error 0.61051079723984
# Meta Valid Accuracy 0.7912499979138374
#
#
# Iteration 85
# Meta Train Error 0.44171726843342185
# Meta Train Accuracy 0.8449999988079071
# Meta Valid Error 0.5194050255231559
# Meta Valid Accuracy 0.8224999960511923
#
#
# Iteration 86
# Meta Train Error 0.47459212969988585
# Meta Train Accuracy 0.8399999961256981
# Meta Valid Error 0.5477370489388704
# Meta Valid Accuracy 0.8037499990314245
#
#
# Iteration 87
# Meta Train Error 0.45956283574923873
# Meta Train Accuracy 0.8399999979883432
# Meta Valid Error 0.5637715305201709
# Meta Valid Accuracy 0.7887500021606684
#
#
# Iteration 88
# Meta Train Error 0.4143324194010347
# Meta Train Accuracy 0.8724999967962503
# Meta Valid Error 0.5340557182207704
# Meta Valid Accuracy 0.8100000023841858
#
#
# Iteration 89
# Meta Train Error 0.49387504160404205
# Meta Train Accuracy 0.8225000016391277
# Meta Valid Error 0.5309942794265226
# Meta Valid Accuracy 0.7962499996647239
#
#
# Iteration 90
# Meta Train Error 0.4412544444203377
# Meta Train Accuracy 0.8424999956041574
# Meta Valid Error 0.5034507228992879
# Meta Valid Accuracy 0.8224999979138374
#
#
# Iteration 91
# Meta Train Error 0.40961170429363847
# Meta Train Accuracy 0.8662499971687794
# Meta Valid Error 0.5482903271913528
# Meta Valid Accuracy 0.8037499925121665
#
#
# Iteration 92
# Meta Train Error 0.42853265162557364
# Meta Train Accuracy 0.8512499984353781
# Meta Valid Error 0.5596888680011034
# Meta Valid Accuracy 0.7899999991059303
#
#
# Iteration 93
# Meta Train Error 0.43416738836094737
# Meta Train Accuracy 0.8424999956041574
# Meta Valid Error 0.5070633012801409
# Meta Valid Accuracy 0.8112499983981252
#
#
# Iteration 94
# Meta Train Error 0.4435164425522089
# Meta Train Accuracy 0.8462499957531691
# Meta Valid Error 0.5161934578791261
# Meta Valid Accuracy 0.8099999967962503
#
#
# Iteration 95
# Meta Train Error 0.38315369095653296
# Meta Train Accuracy 0.875
# Meta Valid Error 0.529915458522737
# Meta Valid Accuracy 0.8049999997019768
#
#
# Iteration 96
# Meta Train Error 0.440017722081393
# Meta Train Accuracy 0.858749995008111
# Meta Valid Error 0.5736865880899131
# Meta Valid Accuracy 0.8025000020861626
#
#
# Iteration 97
# Meta Train Error 0.41406202921643853
# Meta Train Accuracy 0.8637499995529652
# Meta Valid Error 0.49520417815074325
# Meta Valid Accuracy 0.81124999653548
#
#
# Iteration 98
# Meta Train Error 0.40860718698240817
# Meta Train Accuracy 0.8587500005960464
# Meta Valid Error 0.5737112704664469
# Meta Valid Accuracy 0.7887500002980232
#
#
# Iteration 99
# Meta Train Error 0.46401784545741975
# Meta Train Accuracy 0.8412499967962503
# Meta Valid Error 0.46375641832128167
# Meta Valid Accuracy 0.8362499978393316
#
#
# Iteration 100
# Meta Train Error 0.41073245368897915
# Meta Train Accuracy 0.8612500000745058
# Meta Valid Error 0.4858329223934561
# Meta Valid Accuracy 0.8274999987334013
# Iteration 101
# Meta Train Error 0.4068642808124423
# Meta Train Accuracy 0.8612499963492155
# Meta Valid Error 0.4615884420927614
# Meta Valid Accuracy 0.8412499986588955
#
#
# Iteration 102
# Meta Train Error 0.37257821252569556
# Meta Train Accuracy 0.8774999938905239
# Meta Valid Error 0.5567077035084367
# Meta Valid Accuracy 0.798750001937151
#
#
# Iteration 103
# Meta Train Error 0.3660126437898725
# Meta Train Accuracy 0.8775000013411045
# Meta Valid Error 0.4825038560666144
# Meta Valid Accuracy 0.8249999973922968
#
#
# Iteration 104
# Meta Train Error 0.42495828215032816
# Meta Train Accuracy 0.8474999945610762
# Meta Valid Error 0.4416588945314288
# Meta Valid Accuracy 0.837500000372529
#
#
# Iteration 105
# Meta Train Error 0.41561083612032235
# Meta Train Accuracy 0.8400000017136335
# Meta Valid Error 0.4820490009151399
# Meta Valid Accuracy 0.8187500014901161
#
#
# Iteration 106
# Meta Train Error 0.44474571268074214
# Meta Train Accuracy 0.8475000001490116
# Meta Valid Error 0.4874760943930596
# Meta Valid Accuracy 0.8349999953061342
#
#
# Iteration 107
# Meta Train Error 0.4416056100744754
# Meta Train Accuracy 0.8387499991804361
# Meta Valid Error 0.45287478109821677
# Meta Valid Accuracy 0.8474999982863665
#
#
# Iteration 108
# Meta Train Error 0.3945382977835834
# Meta Train Accuracy 0.8499999940395355
# Meta Valid Error 0.4235532912425697
# Meta Valid Accuracy 0.857499998062849
#
#
# Iteration 109
# Meta Train Error 0.39301885780878365
# Meta Train Accuracy 0.8662499971687794
# Meta Valid Error 0.5080423606559634
# Meta Valid Accuracy 0.8112500011920929
#
#
# Iteration 110
# Meta Train Error 0.36134283151477575
# Meta Train Accuracy 0.8649999983608723
# Meta Valid Error 0.46713787491898984
# Meta Valid Accuracy 0.8162499964237213
#
#
# Iteration 111
# Meta Train Error 0.39142615033779293
# Meta Train Accuracy 0.8712500017136335
# Meta Valid Error 0.499457526486367
# Meta Valid Accuracy 0.826249998062849
#
#
# Iteration 112
# Meta Train Error 0.3811211781576276
# Meta Train Accuracy 0.875
# Meta Valid Error 0.5009266268461943
# Meta Valid Accuracy 0.8225000016391277
#
#
# Iteration 113
# Meta Train Error 0.4465573711786419
# Meta Train Accuracy 0.8462499976158142
# Meta Valid Error 0.45988550363108516
# Meta Valid Accuracy 0.8350000027567148
#
#
# Iteration 114
# Meta Train Error 0.3758730539120734
# Meta Train Accuracy 0.8787499964237213
# Meta Valid Error 0.41133388807065785
# Meta Valid Accuracy 0.8475000020116568
#
#
# Iteration 115
# Meta Train Error 0.4427218690980226
# Meta Train Accuracy 0.8349999990314245
# Meta Valid Error 0.553157031070441
# Meta Valid Accuracy 0.8000000007450581
#
#
# Iteration 116
# Meta Train Error 0.33193516568280756
# Meta Train Accuracy 0.881249999627471
# Meta Valid Error 0.3894674498587847
# Meta Valid Accuracy 0.8687499985098839
#
#
# Iteration 117
# Meta Train Error 0.3259196088183671
# Meta Train Accuracy 0.8787499982863665
# Meta Valid Error 0.5108492756262422
# Meta Valid Accuracy 0.8212500009685755
#
#
# Iteration 118
# Meta Train Error 0.38000338803976774
# Meta Train Accuracy 0.8624999932944775
# Meta Valid Error 0.4608996668830514
# Meta Valid Accuracy 0.8462500013411045
#
#
# Iteration 119
# Meta Train Error 0.3806603169068694
# Meta Train Accuracy 0.875
# Meta Valid Error 0.4864261304028332
# Meta Valid Accuracy 0.8249999955296516
#
#
# Iteration 120
# Meta Train Error 0.36975689977407455
# Meta Train Accuracy 0.8750000018626451
# Meta Valid Error 0.463646711781621
# Meta Valid Accuracy 0.8337499983608723
#
#
# Iteration 121
# Meta Train Error 0.40370623557828367
# Meta Train Accuracy 0.8712499998509884
# Meta Valid Error 0.3846536793280393
# Meta Valid Accuracy 0.8662499953061342
#
#
# Iteration 122
# Meta Train Error 0.4503236507298425
# Meta Train Accuracy 0.857499998062849
# Meta Valid Error 0.4367769183591008
# Meta Valid Accuracy 0.8487499952316284
#
#
# Iteration 123
# Meta Train Error 0.4375730324536562
# Meta Train Accuracy 0.8300000000745058
# Meta Valid Error 0.39376350305974483
# Meta Valid Accuracy 0.8599999975413084
#
#
# Iteration 124
# Meta Train Error 0.33008253248408437
# Meta Train Accuracy 0.8937499988824129
# Meta Valid Error 0.4538525315001607
# Meta Valid Accuracy 0.8424999937415123
#
#
# Iteration 125
# Meta Train Error 0.3806111025623977
# Meta Train Accuracy 0.8774999994784594
# Meta Valid Error 0.46037503704428673
# Meta Valid Accuracy 0.8399999942630529
#
#
# Iteration 126
# Meta Train Error 0.3664008773630485
# Meta Train Accuracy 0.8599999938160181
# Meta Valid Error 0.4472565471660346
# Meta Valid Accuracy 0.8449999988079071
#
#
# Iteration 127
# Meta Train Error 0.39842016343027353
# Meta Train Accuracy 0.8562499955296516
# Meta Valid Error 0.4440005221404135
# Meta Valid Accuracy 0.8425000011920929
#
#
# Iteration 128
# Meta Train Error 0.4894356238655746
# Meta Train Accuracy 0.8287499975413084
# Meta Valid Error 0.4560703160241246
# Meta Valid Accuracy 0.8337499964982271
#
#
# Iteration 129
# Meta Train Error 0.38319242745637894
# Meta Train Accuracy 0.869999997317791
# Meta Valid Error 0.38857047364581376
# Meta Valid Accuracy 0.8674999978393316
#
#
# Iteration 130
# Meta Train Error 0.4474787935614586
# Meta Train Accuracy 0.8299999991431832
# Meta Valid Error 0.43838762305676937
# Meta Valid Accuracy 0.842500003054738
#
#
# Iteration 131
# Meta Train Error 0.3569696965860203
# Meta Train Accuracy 0.8787499889731407
# Meta Valid Error 0.4863046263344586
# Meta Valid Accuracy 0.8200000040233135
#
#
# Iteration 132
# Meta Train Error 0.3358793806983158
# Meta Train Accuracy 0.8824999984353781
# Meta Valid Error 0.3341991148190573
# Meta Valid Accuracy 0.8900000024586916
#
#
# Iteration 133
# Meta Train Error 0.3425000826828182
# Meta Train Accuracy 0.8837499972432852
# Meta Valid Error 0.3929342092014849
# Meta Valid Accuracy 0.8687499929219484
#
#
# Iteration 134
# Meta Train Error 0.38790202466771007
# Meta Train Accuracy 0.8787499945610762
# Meta Valid Error 0.4435625246260315
# Meta Valid Accuracy 0.8650000002235174
#
#
# Iteration 135
# Meta Train Error 0.33613232302013785
# Meta Train Accuracy 0.8974999915808439
# Meta Valid Error 0.3755975349340588
# Meta Valid Accuracy 0.8662499915808439
#
#
# Iteration 136
# Meta Train Error 0.3454140843823552
# Meta Train Accuracy 0.8749999962747097
# Meta Valid Error 0.44573803851380944
# Meta Valid Accuracy 0.8387500047683716
#
#
# Iteration 137
# Meta Train Error 0.33896989084314555
# Meta Train Accuracy 0.8862499967217445
# Meta Valid Error 0.37118752719834447
# Meta Valid Accuracy 0.8749999944120646
#
#
# Iteration 138
# Meta Train Error 0.341418654890731
# Meta Train Accuracy 0.8799999933689833
# Meta Valid Error 0.4199946974404156
# Meta Valid Accuracy 0.8537499997764826
#
#
# Iteration 139
# Meta Train Error 0.4615836259908974
# Meta Train Accuracy 0.8387499991804361
# Meta Valid Error 0.41582965292036533
# Meta Valid Accuracy 0.8574999943375587
#
#
# Iteration 140
# Meta Train Error 0.2889552938286215
# Meta Train Accuracy 0.9187499955296516
# Meta Valid Error 0.4598996425047517
# Meta Valid Accuracy 0.8287499956786633
#
#
# Iteration 141
# Meta Train Error 0.39240598026663065
# Meta Train Accuracy 0.8650000002235174
# Meta Valid Error 0.3757448031101376
# Meta Valid Accuracy 0.8637499958276749
#
#
# Iteration 142
# Meta Train Error 0.37891256832517684
# Meta Train Accuracy 0.8749999981373549
# Meta Valid Error 0.40930402325466275
# Meta Valid Accuracy 0.8524999972432852
#
#
# Iteration 143
# Meta Train Error 0.31668212031945586
# Meta Train Accuracy 0.8924999926239252
# Meta Valid Error 0.4129843330010772
# Meta Valid Accuracy 0.8587499968707561
#
#
# Iteration 144
# Meta Train Error 0.2846189374104142
# Meta Train Accuracy 0.9062499962747097
# Meta Valid Error 0.35991376475431025
# Meta Valid Accuracy 0.8800000008195639
#
#
# Iteration 145
# Meta Train Error 0.3872705844696611
# Meta Train Accuracy 0.8649999983608723
# Meta Valid Error 0.3923710617236793
# Meta Valid Accuracy 0.8637499958276749
#
#
# Iteration 146
# Meta Train Error 0.32477873063180596
# Meta Train Accuracy 0.8974999934434891
# Meta Valid Error 0.4172732145525515
# Meta Valid Accuracy 0.8549999948590994
#
#
# Iteration 147
# Meta Train Error 0.3354398621013388
# Meta Train Accuracy 0.8912500031292439
# Meta Valid Error 0.4026026977226138
# Meta Valid Accuracy 0.858749995008111
#
#
# Iteration 148
# Meta Train Error 0.34107176889665425
# Meta Train Accuracy 0.8787499945610762
# Meta Valid Error 0.4854794112034142
# Meta Valid Accuracy 0.8212499972432852
#
#
# Iteration 149
# Meta Train Error 0.3196328766644001
# Meta Train Accuracy 0.8875000011175871
# Meta Valid Error 0.46568400342948735
# Meta Valid Accuracy 0.8424999993294477
#
#
# Iteration 150
# Meta Train Error 0.32867167913354933
# Meta Train Accuracy 0.8899999968707561
# Meta Valid Error 0.3698957650922239
# Meta Valid Accuracy 0.8762499932199717
# Iteration 151
# Meta Train Error 0.35462665162049234
# Meta Train Accuracy 0.8774999976158142
# Meta Valid Error 0.42801580345258117
# Meta Valid Accuracy 0.8562499973922968
#
#
# Iteration 152
# Meta Train Error 0.2809527018107474
# Meta Train Accuracy 0.9137499984353781
# Meta Valid Error 0.34081632690504193
# Meta Valid Accuracy 0.878749992698431
#
#
# Iteration 153
# Meta Train Error 0.30456839001271874
# Meta Train Accuracy 0.8962499983608723
# Meta Valid Error 0.411830335855484
# Meta Valid Accuracy 0.8500000014901161
#
#
# Iteration 154
# Meta Train Error 0.2779368464834988
# Meta Train Accuracy 0.9037499986588955
# Meta Valid Error 0.3696462311781943
# Meta Valid Accuracy 0.8774999938905239
#
#
# Iteration 155
# Meta Train Error 0.32053715881193057
# Meta Train Accuracy 0.8899999894201756
# Meta Valid Error 0.37894187250640243
# Meta Valid Accuracy 0.8737499993294477
#
#
# Iteration 156
# Meta Train Error 0.27366888837423176
# Meta Train Accuracy 0.8962499983608723
# Meta Valid Error 0.3819354916922748
# Meta Valid Accuracy 0.8624999988824129
#
#
# Iteration 157
# Meta Train Error 0.294865946052596
# Meta Train Accuracy 0.8875000011175871
# Meta Valid Error 0.33805590379051864
# Meta Valid Accuracy 0.8862499967217445
#
#
# Iteration 158
# Meta Train Error 0.29611434089019895
# Meta Train Accuracy 0.8987499978393316
# Meta Valid Error 0.3459125878289342
# Meta Valid Accuracy 0.8724999912083149
#
#
# Iteration 159
# Meta Train Error 0.3639322837116197
# Meta Train Accuracy 0.8712499942630529
# Meta Valid Error 0.3196446509100497
# Meta Valid Accuracy 0.8900000024586916
#
#
# Iteration 160
# Meta Train Error 0.2382529720198363
# Meta Train Accuracy 0.9250000026077032
# Meta Valid Error 0.4061734895221889
# Meta Valid Accuracy 0.8499999977648258
#
#
# Iteration 161
# Meta Train Error 0.3743245725054294
# Meta Train Accuracy 0.8749999962747097
# Meta Valid Error 0.31519337836652994
# Meta Valid Accuracy 0.8925000000745058
#
#
# Iteration 162
# Meta Train Error 0.3260640995576978
# Meta Train Accuracy 0.8962499964982271
# Meta Valid Error 0.36879635439254344
# Meta Valid Accuracy 0.8774999957531691
#
#
# Iteration 163
# Meta Train Error 0.3092564116232097
# Meta Train Accuracy 0.9049999881535769
# Meta Valid Error 0.34949709055945277
# Meta Valid Accuracy 0.8824999947100878
#
#
# Iteration 164
# Meta Train Error 0.3144967657281086
# Meta Train Accuracy 0.8949999958276749
# Meta Valid Error 0.3549938548821956
# Meta Valid Accuracy 0.8774999957531691
#
#
# Iteration 165
# Meta Train Error 0.31469476711936295
# Meta Train Accuracy 0.8849999941885471
# Meta Valid Error 0.34419211908243597
# Meta Valid Accuracy 0.8712500017136335
#
#
# Iteration 166
# Meta Train Error 0.31962338858284056
# Meta Train Accuracy 0.8862499929964542
# Meta Valid Error 0.3976907392498106
# Meta Valid Accuracy 0.8537499960511923
#
#
# Iteration 167
# Meta Train Error 0.343352846801281
# Meta Train Accuracy 0.8687500022351742
# Meta Valid Error 0.3502175617031753
# Meta Valid Accuracy 0.8812499921768904
#
#
# Iteration 168
# Meta Train Error 0.34247340413276106
# Meta Train Accuracy 0.8749999962747097
# Meta Valid Error 0.32673175260424614
# Meta Valid Accuracy 0.88625000230968
#
#
# Iteration 169
# Meta Train Error 0.26018884673248976
# Meta Train Accuracy 0.9137499909847975
# Meta Valid Error 0.3214844383765012
# Meta Valid Accuracy 0.8974999971687794
#
#
# Iteration 170
# Meta Train Error 0.3135261811548844
# Meta Train Accuracy 0.8937500007450581
# Meta Valid Error 0.3375831700395793
# Meta Valid Accuracy 0.8787499964237213
#
#
# Iteration 171
# Meta Train Error 0.2827416792861186
# Meta Train Accuracy 0.8937499951571226
# Meta Valid Error 0.2917789398925379
# Meta Valid Accuracy 0.9024999942630529
#
#
# Iteration 172
# Meta Train Error 0.31690519815310836
# Meta Train Accuracy 0.8987499978393316
# Meta Valid Error 0.32401650230167434
# Meta Valid Accuracy 0.9037500005215406
#
#
# Iteration 173
# Meta Train Error 0.30040157039184123
# Meta Train Accuracy 0.8974999971687794
# Meta Valid Error 0.3876721865963191
# Meta Valid Accuracy 0.86374999769032
#
#
# Iteration 174
# Meta Train Error 0.32762375799939036
# Meta Train Accuracy 0.8949999958276749
# Meta Valid Error 0.345134190749377
# Meta Valid Accuracy 0.8687499966472387
#
#
# Iteration 175
# Meta Train Error 0.311888694181107
# Meta Train Accuracy 0.8949999939650297
# Meta Valid Error 0.32092329929582775
# Meta Valid Accuracy 0.8962500020861626
#
#
# Iteration 176
# Meta Train Error 0.2928107639309019
# Meta Train Accuracy 0.8874999955296516
# Meta Valid Error 0.35391463339328766
# Meta Valid Accuracy 0.8737499937415123
#
#
# Iteration 177
# Meta Train Error 0.2814249671064317
# Meta Train Accuracy 0.9049999974668026
# Meta Valid Error 0.2592841583536938
# Meta Valid Accuracy 0.9174999985843897
#
#
# Iteration 178
# Meta Train Error 0.26473806251306087
# Meta Train Accuracy 0.9187499955296516
# Meta Valid Error 0.3360058453399688
# Meta Valid Accuracy 0.8825000002980232
#
#
# Iteration 179
# Meta Train Error 0.27624205802567303
# Meta Train Accuracy 0.9049999937415123
# Meta Valid Error 0.35780188301578164
# Meta Valid Accuracy 0.8612500000745058
#
#
# Iteration 180
# Meta Train Error 0.31398087460547686
# Meta Train Accuracy 0.9049999937415123
# Meta Valid Error 0.33403295185416937
# Meta Valid Accuracy 0.8862499967217445
#
#
# Iteration 181
# Meta Train Error 0.30492673156550154
# Meta Train Accuracy 0.8849999979138374
# Meta Valid Error 0.335525824513752
# Meta Valid Accuracy 0.888749998062849
#
#
# Iteration 182
# Meta Train Error 0.23548823315650225
# Meta Train Accuracy 0.922499991953373
# Meta Valid Error 0.27948113600723445
# Meta Valid Accuracy 0.907499996945262
#
#
# Iteration 183
# Meta Train Error 0.30626158439554274
# Meta Train Accuracy 0.8874999955296516
# Meta Valid Error 0.3614574323873967
# Meta Valid Accuracy 0.8712500035762787
#
#
# Iteration 184
# Meta Train Error 0.30035671673249453
# Meta Train Accuracy 0.8974999990314245
# Meta Valid Error 0.3038292901474051
# Meta Valid Accuracy 0.8974999953061342
#
#
# Iteration 185
# Meta Train Error 0.2613211562857032
# Meta Train Accuracy 0.9087499938905239
# Meta Valid Error 0.3059073572512716
# Meta Valid Accuracy 0.8787499908357859
#
#
# Iteration 186
# Meta Train Error 0.2647156440652907
# Meta Train Accuracy 0.9124999921768904
# Meta Valid Error 0.31042296439409256
# Meta Valid Accuracy 0.8837499991059303
#
#
# Iteration 187
# Meta Train Error 0.21878799644764513
# Meta Train Accuracy 0.9249999932944775
# Meta Valid Error 0.3130630116793327
# Meta Valid Accuracy 0.8874999936670065
#
#
# Iteration 188
# Meta Train Error 0.23304107855074108
# Meta Train Accuracy 0.9237499982118607
# Meta Valid Error 0.358276977436617
# Meta Valid Accuracy 0.8699999954551458
#
#
# Iteration 189
# Meta Train Error 0.24785358464578167
# Meta Train Accuracy 0.9049999974668026
# Meta Valid Error 0.33686049771495163
# Meta Valid Accuracy 0.8812499959021807
#
#
# Iteration 190
# Meta Train Error 0.24101071036420763
# Meta Train Accuracy 0.9137499947100878
# Meta Valid Error 0.35849997750483453
# Meta Valid Accuracy 0.8824999947100878
#
#
# Iteration 191
# Meta Train Error 0.3141039985930547
# Meta Train Accuracy 0.8874999936670065
# Meta Valid Error 0.293756908737123
# Meta Valid Accuracy 0.9049999956041574
#
#
# Iteration 192
# Meta Train Error 0.3188128031324595
# Meta Train Accuracy 0.8924999944865704
# Meta Valid Error 0.3298844792880118
# Meta Valid Accuracy 0.8849999979138374
#
#
# Iteration 193
# Meta Train Error 0.2691088516730815
# Meta Train Accuracy 0.8962499909102917
# Meta Valid Error 0.301897584926337
# Meta Valid Accuracy 0.8912499938160181
#
#
# Iteration 194
# Meta Train Error 0.21191719081252813
# Meta Train Accuracy 0.9337499924004078
# Meta Valid Error 0.30147465935442597
# Meta Valid Accuracy 0.8862499967217445
#
#
# Iteration 195
# Meta Train Error 0.28623451688326895
# Meta Train Accuracy 0.8974999990314245
# Meta Valid Error 0.3484627944417298
# Meta Valid Accuracy 0.8812499977648258
#
#
# Iteration 196
# Meta Train Error 0.2252179989591241
# Meta Train Accuracy 0.9312499947845936
# Meta Valid Error 0.26389506296254694
# Meta Valid Accuracy 0.9037499912083149
#
#
# Iteration 197
# Meta Train Error 0.23013989673927426
# Meta Train Accuracy 0.919999998062849
# Meta Valid Error 0.3142364085651934
# Meta Valid Accuracy 0.8787499964237213
#
#
# Iteration 198
# Meta Train Error 0.30593369831331074
# Meta Train Accuracy 0.8974999971687794
# Meta Valid Error 0.30721810762770474
# Meta Valid Accuracy 0.8887499962002039
#
#
# Iteration 199
# Meta Train Error 0.252462052507326
# Meta Train Accuracy 0.9199999962002039
# Meta Valid Error 0.2819764974992722
# Meta Valid Accuracy 0.907499996945262
#
#
# Iteration 200
# Meta Train Error 0.25100103043951094
# Meta Train Accuracy 0.9187499936670065
# Meta Valid Error 0.33852668257895857
# Meta Valid Accuracy 0.8762499932199717
# Iteration 201
# Meta Train Error 0.24707239301642403
# Meta Train Accuracy 0.9137499965727329
# Meta Valid Error 0.29126606264617294
# Meta Valid Accuracy 0.8962500020861626
#
#
# Iteration 202
# Meta Train Error 0.3089115236653015
# Meta Train Accuracy 0.8974999915808439
# Meta Valid Error 0.3212393276626244
# Meta Valid Accuracy 0.8987499997019768
#
#
# Iteration 203
# Meta Train Error 0.2849200149066746
# Meta Train Accuracy 0.90374999307096
# Meta Valid Error 0.28353696735575795
# Meta Valid Accuracy 0.8887499943375587
#
#
# Iteration 204
# Meta Train Error 0.2736281306715682
# Meta Train Accuracy 0.9024999979883432
# Meta Valid Error 0.3571910404134542
# Meta Valid Accuracy 0.8799999970942736
#
#
# Iteration 205
# Meta Train Error 0.2551861989777535
# Meta Train Accuracy 0.9225000031292439
# Meta Valid Error 0.3153311505448073
# Meta Valid Accuracy 0.8837499972432852
#
#
# Iteration 206
# Meta Train Error 0.27101614652201533
# Meta Train Accuracy 0.907499996945262
# Meta Valid Error 0.25466814381070435
# Meta Valid Accuracy 0.9112499989569187
#
#
# Iteration 207
# Meta Train Error 0.20011555217206478
# Meta Train Accuracy 0.9299999922513962
# Meta Valid Error 0.29687803518027067
# Meta Valid Accuracy 0.8899999931454659
#
#
# Iteration 208
# Meta Train Error 0.23468572355341166
# Meta Train Accuracy 0.9137499947100878
# Meta Valid Error 0.26570044411346316
# Meta Valid Accuracy 0.9087499920278788
#
#
# Iteration 209
# Meta Train Error 0.3229121108306572
# Meta Train Accuracy 0.8874999973922968
# Meta Valid Error 0.27007862087339163
# Meta Valid Accuracy 0.9124999940395355
#
#
# Iteration 210
# Meta Train Error 0.2350665956037119
# Meta Train Accuracy 0.9237500000745058
# Meta Valid Error 0.31039345217868686
# Meta Valid Accuracy 0.8862499967217445
#
#
# Iteration 211
# Meta Train Error 0.22077987325610593
# Meta Train Accuracy 0.9362499956041574
# Meta Valid Error 0.25899098406080157
# Meta Valid Accuracy 0.8987499978393316
#
#
# Iteration 212
# Meta Train Error 0.2530317681375891
# Meta Train Accuracy 0.9187499992549419
# Meta Valid Error 0.2948245246661827
# Meta Valid Accuracy 0.907499996945262
#
#
# Iteration 213
# Meta Train Error 0.21936965791974217
# Meta Train Accuracy 0.9274999983608723
# Meta Valid Error 0.30948543339036405
# Meta Valid Accuracy 0.8962499964982271
#
#
# Iteration 214
# Meta Train Error 0.229777354397811
# Meta Train Accuracy 0.9124999921768904
# Meta Valid Error 0.2534104008227587
# Meta Valid Accuracy 0.90374999307096
#
#
# Iteration 215
# Meta Train Error 0.24357644439442083
# Meta Train Accuracy 0.9187499973922968
# Meta Valid Error 0.33048488839995116
# Meta Valid Accuracy 0.8824999909847975
#
#
# Iteration 216
# Meta Train Error 0.27877537719905376
# Meta Train Accuracy 0.8999999947845936
# Meta Valid Error 0.27621042472310364
# Meta Valid Accuracy 0.9037499967962503
#
#
# Iteration 217
# Meta Train Error 0.2625297767808661
# Meta Train Accuracy 0.9100000020116568
# Meta Valid Error 0.30958070245105773
# Meta Valid Accuracy 0.8987499959766865
#
#
# Iteration 218
# Meta Train Error 0.2502820346853696
# Meta Train Accuracy 0.9237499907612801
# Meta Valid Error 0.27100385061930865
# Meta Valid Accuracy 0.9049999993294477
#
#
# Iteration 219
# Meta Train Error 0.26433235104195774
# Meta Train Accuracy 0.9075000043958426
# Meta Valid Error 0.32217889663297683
# Meta Valid Accuracy 0.888749998062849
#
#
# Iteration 220
# Meta Train Error 0.26881333137862384
# Meta Train Accuracy 0.9162499960511923
# Meta Valid Error 0.27656265650875866
# Meta Valid Accuracy 0.89499999769032
#
#
# Iteration 221
# Meta Train Error 0.26582905667601153
# Meta Train Accuracy 0.9099999964237213
# Meta Valid Error 0.28839754371438175
# Meta Valid Accuracy 0.89499999769032
#
#
# Iteration 222
# Meta Train Error 0.24883813661290333
# Meta Train Accuracy 0.90374999307096
# Meta Valid Error 0.29692097450606525
# Meta Valid Accuracy 0.8987499997019768
#
#
# Iteration 223
# Meta Train Error 0.22475775855127722
# Meta Train Accuracy 0.9149999897927046
# Meta Valid Error 0.257087573671015
# Meta Valid Accuracy 0.91499999538064
#
#
# Iteration 224
# Meta Train Error 0.30963977612555027
# Meta Train Accuracy 0.8824999928474426
# Meta Valid Error 0.32021527271717787
# Meta Valid Accuracy 0.8949999939650297
#
#
# Iteration 225
# Meta Train Error 0.2532615957316011
# Meta Train Accuracy 0.9162499941885471
# Meta Valid Error 0.2798510855063796
# Meta Valid Accuracy 0.9112499970942736
#
#
# Iteration 226
# Meta Train Error 0.2640127472113818
# Meta Train Accuracy 0.9187499936670065
# Meta Valid Error 0.28927626297809184
# Meta Valid Accuracy 0.9037499986588955
#
#
# Iteration 227
# Meta Train Error 0.2569765804801136
# Meta Train Accuracy 0.9174999985843897
# Meta Valid Error 0.3126276199473068
# Meta Valid Accuracy 0.8949999995529652
#
#
# Iteration 228
# Meta Train Error 0.20878785313107073
# Meta Train Accuracy 0.9399999920278788
# Meta Valid Error 0.330661881249398
# Meta Valid Accuracy 0.888749998062849
#
#
# Iteration 229
# Meta Train Error 0.24379864695947617
# Meta Train Accuracy 0.9162499941885471
# Meta Valid Error 0.2734820180339739
# Meta Valid Accuracy 0.9087499957531691
#
#
# Iteration 230
# Meta Train Error 0.29178812832105905
# Meta Train Accuracy 0.9149999972432852
# Meta Valid Error 0.31726189446635544
# Meta Valid Accuracy 0.8924999944865704
#
#
# Iteration 231
# Meta Train Error 0.2069601971306838
# Meta Train Accuracy 0.9274999964982271
# Meta Valid Error 0.305428933352232
# Meta Valid Accuracy 0.8899999968707561
#
#
# Iteration 232
# Meta Train Error 0.2685913115274161
# Meta Train Accuracy 0.9037499949336052
# Meta Valid Error 0.26708668342325836
# Meta Valid Accuracy 0.9024999979883432
#
#
# Iteration 233
# Meta Train Error 0.23425009258789942
# Meta Train Accuracy 0.9175000004470348
# Meta Valid Error 0.3315769780892879
# Meta Valid Accuracy 0.8899999987334013
#
#
# Iteration 234
# Meta Train Error 0.2344369565253146
# Meta Train Accuracy 0.9324999954551458
# Meta Valid Error 0.24490261124446988
# Meta Valid Accuracy 0.9262499958276749
#
#
# Iteration 235
# Meta Train Error 0.26071621640585363
# Meta Train Accuracy 0.9162499941885471
# Meta Valid Error 0.29288268130039796
# Meta Valid Accuracy 0.9062499962747097
#
#
# Iteration 236
# Meta Train Error 0.26207138344761916
# Meta Train Accuracy 0.8974999971687794
# Meta Valid Error 0.28426012984709814
# Meta Valid Accuracy 0.8987499978393316
#
#
# Iteration 237
# Meta Train Error 0.23442302842158824
# Meta Train Accuracy 0.9312499966472387
# Meta Valid Error 0.23692786565516144
# Meta Valid Accuracy 0.9187499936670065
#
#
# Iteration 238
# Meta Train Error 0.1897110451827757
# Meta Train Accuracy 0.9349999967962503
# Meta Valid Error 0.22363261261489242
# Meta Valid Accuracy 0.9212499968707561
#
#
# Iteration 239
# Meta Train Error 0.23287847242318094
# Meta Train Accuracy 0.9262499995529652
# Meta Valid Error 0.24292367440648377
# Meta Valid Accuracy 0.9187499936670065
#
#
# Iteration 240
# Meta Train Error 0.2459931952180341
# Meta Train Accuracy 0.9187499936670065
# Meta Valid Error 0.2574876875150949
# Meta Valid Accuracy 0.9224999938160181
#
#
# Iteration 241
# Meta Train Error 0.23609569971449673
# Meta Train Accuracy 0.9087499938905239
# Meta Valid Error 0.264897485030815
# Meta Valid Accuracy 0.916249992325902
#
#
# Iteration 242
# Meta Train Error 0.22871673584450036
# Meta Train Accuracy 0.9187499936670065
# Meta Valid Error 0.22575897455681115
# Meta Valid Accuracy 0.9299999978393316
#
#
# Iteration 243
# Meta Train Error 0.31514258636161685
# Meta Train Accuracy 0.8924999944865704
# Meta Valid Error 0.2651055254973471
# Meta Valid Accuracy 0.9012499954551458
#
#
# Iteration 244
# Meta Train Error 0.23940503006451763
# Meta Train Accuracy 0.9262499921023846
# Meta Valid Error 0.30112263245973736
# Meta Valid Accuracy 0.8987499978393316
#
#
# Iteration 245
# Meta Train Error 0.27739372238283977
# Meta Train Accuracy 0.9012499917298555
# Meta Valid Error 0.23689758480759338
# Meta Valid Accuracy 0.9312499910593033
#
#
# Iteration 246
# Meta Train Error 0.23089252691715956
# Meta Train Accuracy 0.9262499958276749
# Meta Valid Error 0.23669466970022768
# Meta Valid Accuracy 0.9249999932944775
#
#
# Iteration 247
# Meta Train Error 0.24957409204216674
# Meta Train Accuracy 0.9112499970942736
# Meta Valid Error 0.21219769108574837
# Meta Valid Accuracy 0.9187500011175871
#
#
# Iteration 248
# Meta Train Error 0.2071198405465111
# Meta Train Accuracy 0.932499997317791
# Meta Valid Error 0.26645724999252707
# Meta Valid Accuracy 0.91499999538064
#
#
# Iteration 249
# Meta Train Error 0.22275437088683248
# Meta Train Accuracy 0.9237499982118607
# Meta Valid Error 0.26552454265765846
# Meta Valid Accuracy 0.9037499949336052
#
#
# Iteration 250
# Meta Train Error 0.2850933998124674
# Meta Train Accuracy 0.9112499933689833
# Meta Valid Error 0.2838406818918884
# Meta Valid Accuracy 0.9062499944120646
# Iteration 251
# Meta Train Error 0.23037701623979956
# Meta Train Accuracy 0.919999998062849
# Meta Valid Error 0.2405779764521867
# Meta Valid Accuracy 0.9162499997764826
#
#
# Iteration 252
# Meta Train Error 0.2969686323776841
# Meta Train Accuracy 0.8950000014156103
# Meta Valid Error 0.2504047908587381
# Meta Valid Accuracy 0.9137500002980232
#
#
# Iteration 253
# Meta Train Error 0.19117928302148357
# Meta Train Accuracy 0.938749996945262
# Meta Valid Error 0.256315587554127
# Meta Valid Accuracy 0.9124999959021807
#
#
# Iteration 254
# Meta Train Error 0.21247798099648207
# Meta Train Accuracy 0.9224999956786633
# Meta Valid Error 0.29706951859407127
# Meta Valid Accuracy 0.8974999934434891
#
#
# Iteration 255
# Meta Train Error 0.18880320701282471
# Meta Train Accuracy 0.9387500006705523
# Meta Valid Error 0.25661282625515014
# Meta Valid Accuracy 0.91499999538064
#
#
# Iteration 256
# Meta Train Error 0.2308747199131176
# Meta Train Accuracy 0.929999990388751
# Meta Valid Error 0.3061440803576261
# Meta Valid Accuracy 0.9037500005215406
#
#
# Iteration 257
# Meta Train Error 0.20752002944936976
# Meta Train Accuracy 0.9387499932199717
# Meta Valid Error 0.25233897933503613
# Meta Valid Accuracy 0.896249994635582
#
#
# Iteration 258
# Meta Train Error 0.2252675702329725
# Meta Train Accuracy 0.9249999988824129
# Meta Valid Error 0.2794291452737525
# Meta Valid Accuracy 0.9025000017136335
#
#
# Iteration 259
# Meta Train Error 0.16992784070316702
# Meta Train Accuracy 0.9437499977648258
# Meta Valid Error 0.27025075152050704
# Meta Valid Accuracy 0.9024999979883432
#
#
# Iteration 260
# Meta Train Error 0.18519639770966023
# Meta Train Accuracy 0.9387500025331974
# Meta Valid Error 0.32570891024079174
# Meta Valid Accuracy 0.8937499951571226
#
#
# Iteration 261
# Meta Train Error 0.24266677495324984
# Meta Train Accuracy 0.9199999943375587
# Meta Valid Error 0.2140022001694888
# Meta Valid Accuracy 0.9237499963492155
#
#
# Iteration 262
# Meta Train Error 0.25726767478045076
# Meta Train Accuracy 0.9112499989569187
# Meta Valid Error 0.26510514359688386
# Meta Valid Accuracy 0.9149999935179949
#
#
# Iteration 263
# Meta Train Error 0.2146933320327662
# Meta Train Accuracy 0.9262499939650297
# Meta Valid Error 0.2643767697736621
# Meta Valid Accuracy 0.9062499944120646
#
#
# Iteration 264
# Meta Train Error 0.20494084304664284
# Meta Train Accuracy 0.9312499985098839
# Meta Valid Error 0.33432900143088773
# Meta Valid Accuracy 0.8724999949336052
#
#
# Iteration 265
# Meta Train Error 0.2657982334494591
# Meta Train Accuracy 0.9100000001490116
# Meta Valid Error 0.25679816701449454
# Meta Valid Accuracy 0.9174999948590994
#
#
# Iteration 266
# Meta Train Error 0.19641015175147913
# Meta Train Accuracy 0.9499999973922968
# Meta Valid Error 0.28815893176943064
# Meta Valid Accuracy 0.8999999966472387
#
#
# Iteration 267
# Meta Train Error 0.1885486442479305
# Meta Train Accuracy 0.9362499974668026
# Meta Valid Error 0.23498330742586404
# Meta Valid Accuracy 0.9224999975413084
#
#
# Iteration 268
# Meta Train Error 0.2502349443966523
# Meta Train Accuracy 0.9074999894946814
# Meta Valid Error 0.2985241876449436
# Meta Valid Accuracy 0.8974999953061342
#
#
# Iteration 269
# Meta Train Error 0.20953000581357628
# Meta Train Accuracy 0.9199999906122684
# Meta Valid Error 0.235539382789284
# Meta Valid Accuracy 0.9187499918043613
#
#
# Iteration 270
# Meta Train Error 0.21712498285342008
# Meta Train Accuracy 0.927499994635582
# Meta Valid Error 0.24805378960445523
# Meta Valid Accuracy 0.9162499941885471
#
#
# Iteration 271
# Meta Train Error 0.28655580698978156
# Meta Train Accuracy 0.8912499994039536
# Meta Valid Error 0.2731168980244547
# Meta Valid Accuracy 0.9187499955296516
#
#
# Iteration 272
# Meta Train Error 0.17134100408293307
# Meta Train Accuracy 0.9512499924749136
# Meta Valid Error 0.20027180557372048
# Meta Valid Accuracy 0.932499997317791
#
#
# Iteration 273
# Meta Train Error 0.21078799874521792
# Meta Train Accuracy 0.9312499966472387
# Meta Valid Error 0.26942621159832925
# Meta Valid Accuracy 0.9012499898672104
#
#
# Iteration 274
# Meta Train Error 0.19834378809900954
# Meta Train Accuracy 0.9199999943375587
# Meta Valid Error 0.27564478234853595
# Meta Valid Accuracy 0.9062499962747097
#
#
# Iteration 275
# Meta Train Error 0.24713562132092193
# Meta Train Accuracy 0.9087499957531691
# Meta Valid Error 0.26955474680289626
# Meta Valid Accuracy 0.9062499962747097
#
#
# Iteration 276
# Meta Train Error 0.24058399960631505
# Meta Train Accuracy 0.9137499928474426
# Meta Valid Error 0.21471071289852262
# Meta Valid Accuracy 0.9187499992549419
#
#
# Iteration 277
# Meta Train Error 0.18430293264100328
# Meta Train Accuracy 0.9424999952316284
# Meta Valid Error 0.3131401806604117
# Meta Valid Accuracy 0.8875000011175871
#
#
# Iteration 278
# Meta Train Error 0.1968049785355106
# Meta Train Accuracy 0.9362499956041574
# Meta Valid Error 0.23061166639672592
# Meta Valid Accuracy 0.9287499934434891
#
#
# Iteration 279
# Meta Train Error 0.20358577539445832
# Meta Train Accuracy 0.9299999959766865
# Meta Valid Error 0.2561948070069775
# Meta Valid Accuracy 0.9162499960511923
#
#
# Iteration 280
# Meta Train Error 0.19292167969979346
# Meta Train Accuracy 0.941249992698431
# Meta Valid Error 0.2814143683644943
# Meta Valid Accuracy 0.9012499954551458
#
#
# Iteration 281
# Meta Train Error 0.23207444458967075
# Meta Train Accuracy 0.9274999983608723
# Meta Valid Error 0.2428839789936319
# Meta Valid Accuracy 0.9224999956786633
#
#
# Iteration 282
# Meta Train Error 0.17947322182590142
# Meta Train Accuracy 0.9374999944120646
# Meta Valid Error 0.25390381808392704
# Meta Valid Accuracy 0.9112500008195639
#
#
# Iteration 283
# Meta Train Error 0.19546458264812827
# Meta Train Accuracy 0.9224999956786633
# Meta Valid Error 0.30080246878787875
# Meta Valid Accuracy 0.8987499941140413
#
#
# Iteration 284
# Meta Train Error 0.19020848959917203
# Meta Train Accuracy 0.9312499929219484
# Meta Valid Error 0.22903781500644982
# Meta Valid Accuracy 0.9275000002235174
#
#
# Iteration 285
# Meta Train Error 0.20702857480500825
# Meta Train Accuracy 0.9324999954551458
# Meta Valid Error 0.22060549643356353
# Meta Valid Accuracy 0.9249999988824129
#
#
# Iteration 286
# Meta Train Error 0.1931893421569839
# Meta Train Accuracy 0.9337499979883432
# Meta Valid Error 0.259480451233685
# ...
# Meta Train Accuracy 0.9562499970197678
# Meta Valid Error 0.21386839446495287
# Meta Valid Accuracy 0.9249999951571226
#
#
# Iteration 589
# Meta Train Error 0.12749458162579685
# Meta Train Accuracy 0.9587499927729368
# Meta Valid Error 0.18701749776664656
# Meta Valid Accuracy 0.9299999997019768
#
#
# Iteration 590
# Meta Train Error 0.15381554698979016
# Meta Train Accuracy 0.9499999973922968
# Meta Valid Error 0.20499538039439358
# Meta Valid Accuracy 0.9174999948590994
#
#
# Iteration 591
# Meta Train Error 0.12646588491043076
# Meta Train Accuracy 0.9574999958276749
# Meta Valid Error 0.20394666178617626
# Meta Valid Accuracy 0.9262499958276749
#
#
# Iteration 592
# Meta Train Error 0.1727253602584824
# Meta Train Accuracy 0.9462499972432852
# Meta Valid Error 0.21722600754583254
# Meta Valid Accuracy 0.9299999978393316
#
#
# Iteration 593
# Meta Train Error 0.16599400728591718
# Meta Train Accuracy 0.9412499889731407
# Meta Valid Error 0.15409735083812848
# Meta Valid Accuracy 0.9387499950826168
#
#
# Iteration 594
# Meta Train Error 0.09402001134003513
# Meta Train Accuracy 0.9749999959021807
# Meta Valid Error 0.18383550713770092
# Meta Valid Accuracy 0.9374999925494194
#
#
# Iteration 595
# Meta Train Error 0.12192984783905558
# Meta Train Accuracy 0.9549999944865704
# Meta Valid Error 0.16769924489199184
# Meta Valid Accuracy 0.9424999933689833
#
#
# Iteration 596
# Meta Train Error 0.11811122923973016
# Meta Train Accuracy 0.9662499949336052
# Meta Valid Error 0.24644789862213656
# Meta Valid Accuracy 0.9162499979138374
#
#
# Iteration 597
# Meta Train Error 0.14622838495415635
# Meta Train Accuracy 0.9524999968707561
# Meta Valid Error 0.16045835529803298
# Meta Valid Accuracy 0.9474999997764826
# Iteration 598
# Meta Train Error 0.11827685168827884
# Meta Train Accuracy 0.9574999921023846
# Meta Valid Error 0.18742793903220445
# Meta Valid Accuracy 0.9299999922513962
#
#
# Iteration 599
# Meta Train Error 0.15004396527365316
# Meta Train Accuracy 0.9437499959021807
# Meta Valid Error 0.18338491322356276
# Meta Valid Accuracy 0.9362499974668026
#
#
# Iteration 600
# Meta Train Error 0.12845829434809275
# Meta Train Accuracy 0.9624999985098839
# Meta Valid Error 0.1628760583116673
# Meta Valid Accuracy 0.947499992325902
#
#
# Iteration 601
# Meta Train Error 0.15932728216284886
# Meta Train Accuracy 0.9537499938160181
# Meta Valid Error 0.19129919007536955
# Meta Valid Accuracy 0.9362499956041574
#
#
# Iteration 602
# Meta Train Error 0.1353548419137951
# Meta Train Accuracy 0.9537499938160181
# Meta Valid Error 0.22312230833631475
# Meta Valid Accuracy 0.9237499963492155
#
#
# Iteration 603
# Meta Train Error 0.1709603594354121
# Meta Train Accuracy 0.9462499972432852
# Meta Valid Error 0.193603589956183
# Meta Valid Accuracy 0.9412499945610762
#
#
# Iteration 604
# Meta Train Error 0.12789663518196903
# Meta Train Accuracy 0.9599999971687794
# Meta Valid Error 0.20151350618107244
# Meta Valid Accuracy 0.922499991953373
#
#
# Iteration 605
# Meta Train Error 0.1297798706800677
# Meta Train Accuracy 0.9637499917298555
# Meta Valid Error 0.2173551047744695
# Meta Valid Accuracy 0.92624999769032
#
#
# Iteration 606
# Meta Train Error 0.14791461983986665
# Meta Train Accuracy 0.9437499977648258
# Meta Valid Error 0.16646351019153371
# Meta Valid Accuracy 0.9374999925494194
#
#
# Iteration 607
# Meta Train Error 0.15100827204878442
# Meta Train Accuracy 0.9462499991059303
# Meta Valid Error 0.1687872772454284
# Meta Valid Accuracy 0.9362499937415123
#
#
# Iteration 608
# Meta Train Error 0.10609098803251982
# Meta Train Accuracy 0.9624999985098839
# Meta Valid Error 0.1682652712042909
# Meta Valid Accuracy 0.9424999915063381
#
#
# Iteration 609
# Meta Train Error 0.12221319586387835
# Meta Train Accuracy 0.9649999905377626
# Meta Valid Error 0.1692223761929199
# Meta Valid Accuracy 0.9487499929964542
#
#
# Iteration 610
# Meta Train Error 0.13761895312927663
# Meta Train Accuracy 0.9537499900907278
# Meta Valid Error 0.16803629911737517
# Meta Valid Accuracy 0.943749999627471
#
#
# Iteration 611
# Meta Train Error 0.14617102217744105
# Meta Train Accuracy 0.9537499938160181
# Meta Valid Error 0.1697276640770724
# Meta Valid Accuracy 0.9412499945610762
#
#
# Iteration 612
# Meta Train Error 0.11133856857486535
# Meta Train Accuracy 0.958749994635582
# Meta Valid Error 0.19019980513257906
# Meta Valid Accuracy 0.9437499921768904
#
#
# Iteration 613
# Meta Train Error 0.14622933372447733
# Meta Train Accuracy 0.9574999958276749
# Meta Valid Error 0.1837233867845498
# Meta Valid Accuracy 0.9312499966472387
#
#
# Iteration 614
# Meta Train Error 0.13841019215760753
# Meta Train Accuracy 0.9524999968707561
# Meta Valid Error 0.19468783473712392
# Meta Valid Accuracy 0.9362499956041574
#
#
# Iteration 615
# Meta Train Error 0.1256761114782421
# Meta Train Accuracy 0.9612499978393316
# Meta Valid Error 0.16550509294029325
# Meta Valid Accuracy 0.9412499964237213
#
#
# Iteration 616
# Meta Train Error 0.1301739402115345
# Meta Train Accuracy 0.9574999921023846
# Meta Valid Error 0.23962407623184845
# Meta Valid Accuracy 0.9262499958276749
#
#
# Iteration 617
# Meta Train Error 0.1426692680834094
# Meta Train Accuracy 0.9487499911338091
# Meta Valid Error 0.2103622752474621
# Meta Valid Accuracy 0.9299999959766865
#
#
# Iteration 618
# Meta Train Error 0.1478717552818125
# Meta Train Accuracy 0.9537499975413084
# Meta Valid Error 0.23122042359318584
# Meta Valid Accuracy 0.9274999964982271
#
#
# Iteration 619
# Meta Train Error 0.12975049306987785
# Meta Train Accuracy 0.952499995008111
# Meta Valid Error 0.18672961060656235
# Meta Valid Accuracy 0.9412499945610762
#
#
# Iteration 620
# Meta Train Error 0.11717768396192696
# Meta Train Accuracy 0.96624999307096
# Meta Valid Error 0.16223681124392897
# Meta Valid Accuracy 0.9512499962002039
#
#
# Iteration 621
# Meta Train Error 0.1322684701444814
# Meta Train Accuracy 0.952499995008111
# Meta Valid Error 0.19410724571207538
# Meta Valid Accuracy 0.9362499974668026
#
#
# Iteration 622
# Meta Train Error 0.12108162610093132
# Meta Train Accuracy 0.9624999929219484
# Meta Valid Error 0.18695168115664274
# Meta Valid Accuracy 0.9374999944120646
#
#
# Iteration 623
# Meta Train Error 0.08903959659073735
# Meta Train Accuracy 0.9662499986588955
# Meta Valid Error 0.13748412864515558
# Meta Valid Accuracy 0.9512499962002039
#
#
# Iteration 624
# Meta Train Error 0.1545931596047012
# Meta Train Accuracy 0.9449999947100878
# Meta Valid Error 0.20653942429635208
# Meta Valid Accuracy 0.9262499958276749
#
#
# Iteration 625
# Meta Train Error 0.13845664911787026
# Meta Train Accuracy 0.9574999958276749
# Meta Valid Error 0.198854846690665
# Meta Valid Accuracy 0.9274999964982271
#
#
# Iteration 626
# Meta Train Error 0.12017526027921122
# Meta Train Accuracy 0.9637499954551458
# Meta Valid Error 0.22909154003718868
# Meta Valid Accuracy 0.9274999983608723
#
#
# Iteration 627
# Meta Train Error 0.09417255803418811
# Meta Train Accuracy 0.969999996945262
# Meta Valid Error 0.18447505429503508
# Meta Valid Accuracy 0.9349999967962503
#
#
# Iteration 628
# Meta Train Error 0.1465274437214248
# Meta Train Accuracy 0.9487499929964542
# Meta Valid Error 0.17661298549501225
# Meta Valid Accuracy 0.9262499995529652
#
#
# Iteration 629
# Meta Train Error 0.11195267544826493
# Meta Train Accuracy 0.9624999929219484
# Meta Valid Error 0.21022976911626756
# Meta Valid Accuracy 0.9337499979883432
#
#
# Iteration 630
# Meta Train Error 0.0777918519161176
# Meta Train Accuracy 0.9762499928474426
# Meta Valid Error 0.21538726188009605
# Meta Valid Accuracy 0.9287499990314245
#
#
# Iteration 631
# Meta Train Error 0.11240785811969545
# Meta Train Accuracy 0.9599999934434891
# Meta Valid Error 0.17538741827593185
# Meta Valid Accuracy 0.9299999959766865
#
#
# Iteration 632
# Meta Train Error 0.13292838774214033
# Meta Train Accuracy 0.9524999931454659
# Meta Valid Error 0.2112865075469017
# Meta Valid Accuracy 0.9362499974668026
#
#
# Iteration 633
# Meta Train Error 0.15637960680760443
# Meta Train Accuracy 0.9462499916553497
# Meta Valid Error 0.11541214319004212
# Meta Valid Accuracy 0.9499999918043613
#
#
# Iteration 634
# Meta Train Error 0.13440805086429464
# Meta Train Accuracy 0.9537499975413084
# Meta Valid Error 0.18987800629111007
# Meta Valid Accuracy 0.9362499956041574
#
#
# Iteration 635
# Meta Train Error 0.12125694681162713
# Meta Train Accuracy 0.9612499922513962
# Meta Valid Error 0.15958418721857015
# Meta Valid Accuracy 0.9474999960511923
#
#
# Iteration 636
# Meta Train Error 0.1167795767687494
# Meta Train Accuracy 0.9649999924004078
# Meta Valid Error 0.22413221065653488
# Meta Valid Accuracy 0.9262499958276749
#
#
# Iteration 637
# Meta Train Error 0.12051382070058025
# Meta Train Accuracy 0.958749994635582
# Meta Valid Error 0.2183481171960011
# Meta Valid Accuracy 0.9312499985098839
#
#
# Iteration 638
# Meta Train Error 0.14122835533635225
# Meta Train Accuracy 0.947499992325902
# Meta Valid Error 0.19071347516728565
# Meta Valid Accuracy 0.9262499958276749
#
#
# Iteration 639
# Meta Train Error 0.11467395516228862
# Meta Train Accuracy 0.9637499935925007
# Meta Valid Error 0.2508937445527408
# Meta Valid Accuracy 0.9099999908357859
#
#
# Iteration 640
# Meta Train Error 0.13364030575030483
# Meta Train Accuracy 0.9487499948590994
# Meta Valid Error 0.19868872297229245
# Meta Valid Accuracy 0.9362499956041574
#
#
# Iteration 641
# Meta Train Error 0.157177169508941
# Meta Train Accuracy 0.9412499945610762
# Meta Valid Error 0.18439119952381589
# Meta Valid Accuracy 0.9437499940395355
#
#
# Iteration 642
# Meta Train Error 0.1492008313362021
# Meta Train Accuracy 0.9562499970197678
# Meta Valid Error 0.2264369746117154
# Meta Valid Accuracy 0.91499999538064
#
#
# Iteration 643
# Meta Train Error 0.17884711113583762
# Meta Train Accuracy 0.9374999944120646
# Meta Valid Error 0.185262254497502
# Meta Valid Accuracy 0.9399999938905239
#
#
# Iteration 644
# Meta Train Error 0.12816678908711765
# Meta Train Accuracy 0.95749999769032
# Meta Valid Error 0.1909889781527454
# Meta Valid Accuracy 0.9374999962747097
#
#
# Iteration 645
# Meta Train Error 0.12460940211894922
# Meta Train Accuracy 0.9624999966472387
# Meta Valid Error 0.1943109539570287
# Meta Valid Accuracy 0.9274999983608723
#
#
# Iteration 646
# Meta Train Error 0.11683966621058062
# Meta Train Accuracy 0.9562499914318323
# Meta Valid Error 0.19835176979540847
# Meta Valid Accuracy 0.9249999932944775
#
#
# Iteration 647
# Meta Train Error 0.12259372064727359
# Meta Train Accuracy 0.9649999961256981
# Meta Valid Error 0.229704097378999
# Meta Valid Accuracy 0.9062499944120646
# Iteration 648
# Meta Train Error 0.11211002862546593
# Meta Train Accuracy 0.9649999961256981
# Meta Valid Error 0.1987654998083599
# Meta Valid Accuracy 0.9237499982118607
#
#
# Iteration 649
# Meta Train Error 0.11101201323617715
# Meta Train Accuracy 0.9649999961256981
# Meta Valid Error 0.1512245779740624
# Meta Valid Accuracy 0.952499995008111
#
#
# Iteration 650
# Meta Train Error 0.15388200742017943
# Meta Train Accuracy 0.9474999941885471
# Meta Valid Error 0.22975535329896957
# Meta Valid Accuracy 0.9187499936670065
#
#
# Iteration 651
# Meta Train Error 0.11051281432446558
# Meta Train Accuracy 0.9624999947845936
# Meta Valid Error 0.20621612333343364
# Meta Valid Accuracy 0.9287499971687794
#
#
# Iteration 652
# Meta Train Error 0.09840411102049984
# Meta Train Accuracy 0.9674999956041574
# Meta Valid Error 0.20724281016737223
# Meta Valid Accuracy 0.9374999906867743
#
#
# Iteration 653
# Meta Train Error 0.12257143622264266
# Meta Train Accuracy 0.9537499956786633
# Meta Valid Error 0.1821189132751897
# Meta Valid Accuracy 0.93499999307096
#
#
# Iteration 654
# Meta Train Error 0.11820944042119663
# Meta Train Accuracy 0.9599999971687794
# Meta Valid Error 0.1735605874855537
# Meta Valid Accuracy 0.9424999933689833
#
#
# Iteration 655
# Meta Train Error 0.1486353407090064
# Meta Train Accuracy 0.9599999990314245
# Meta Valid Error 0.17856598006619606
# Meta Valid Accuracy 0.9387499950826168
#
#
# Iteration 656
# Meta Train Error 0.11682842129084747
# Meta Train Accuracy 0.9587499927729368
# Meta Valid Error 0.20237678998091724
# Meta Valid Accuracy 0.927499994635582
#
#
# Iteration 657
# Meta Train Error 0.14693152296240442
# Meta Train Accuracy 0.9587499927729368
# Meta Valid Error 0.2041330723441206
# Meta Valid Accuracy 0.9174999948590994
#
#
# Iteration 658
# Meta Train Error 0.17929391728830524
# Meta Train Accuracy 0.9399999957531691
# Meta Valid Error 0.16326028743060306
# Meta Valid Accuracy 0.9437499977648258
#
#
# Iteration 659
# Meta Train Error 0.12786069887806661
# Meta Train Accuracy 0.9562499988824129
# Meta Valid Error 0.20184110139962286
# Meta Valid Accuracy 0.9224999938160181
#
#
# Iteration 660
# Meta Train Error 0.12404811772285029
# Meta Train Accuracy 0.9574999921023846
# Meta Valid Error 0.1553000223066192
# Meta Valid Accuracy 0.9449999928474426
#
#
# Iteration 661
# Meta Train Error 0.11128281432320364
# Meta Train Accuracy 0.9624999910593033
# Meta Valid Error 0.19972260377835482
# Meta Valid Accuracy 0.9312499985098839
#
#
# Iteration 662
# Meta Train Error 0.13997771285357885
# Meta Train Accuracy 0.962500000372529
# Meta Valid Error 0.21069014399836306
# Meta Valid Accuracy 0.9237499963492155
#
#
# Iteration 663
# Meta Train Error 0.09085303773463238
# Meta Train Accuracy 0.9699999932199717
# Meta Valid Error 0.21970589767443016
# Meta Valid Accuracy 0.9299999978393316
#
#
# Iteration 664
# Meta Train Error 0.14115163491806015
# Meta Train Accuracy 0.9487499929964542
# Meta Valid Error 0.2171505078440532
# Meta Valid Accuracy 0.9262499958276749
#
#
# Iteration 665
# Meta Train Error 0.1200800196675118
# Meta Train Accuracy 0.9599999971687794
# Meta Valid Error 0.19879195205430733
# Meta Valid Accuracy 0.9349999949336052
#
#
# Iteration 666
# Meta Train Error 0.14722059525956865
# Meta Train Accuracy 0.952499995008111
# Meta Valid Error 0.22749115826445632
# Meta Valid Accuracy 0.9162500016391277
#
#
# Iteration 667
# Meta Train Error 0.12950801980332471
# Meta Train Accuracy 0.9537499956786633
# Meta Valid Error 0.2045863051826018
# Meta Valid Accuracy 0.9337499961256981
#
#
# Iteration 668
# Meta Train Error 0.12759997393004596
# Meta Train Accuracy 0.9562499914318323
# Meta Valid Error 0.1896437601535581
# Meta Valid Accuracy 0.9362499956041574
#
#
# Iteration 669
# Meta Train Error 0.17427920665068086
# Meta Train Accuracy 0.9424999970942736
# Meta Valid Error 0.16731983629870228
# Meta Valid Accuracy 0.9437500014901161
#
#
# Iteration 670
# Meta Train Error 0.1901015985349659
# Meta Train Accuracy 0.9287499971687794
# Meta Valid Error 0.15908028709236532
# Meta Valid Accuracy 0.9437499921768904
#
#
# Iteration 671
# Meta Train Error 0.16049215069506317
# Meta Train Accuracy 0.94624999538064
# Meta Valid Error 0.19445823624846525
# Meta Valid Accuracy 0.9337499942630529
#
#
# Iteration 672
# Meta Train Error 0.17215603204385843
# Meta Train Accuracy 0.9387499950826168
# Meta Valid Error 0.14127663045655936
# Meta Valid Accuracy 0.9462499916553497
#
#
# Iteration 673
# Meta Train Error 0.11586603592149913
# Meta Train Accuracy 0.9587499983608723
# Meta Valid Error 0.1984456191130448
# Meta Valid Accuracy 0.9274999927729368
#
#
# Iteration 674
# Meta Train Error 0.11705169297056273
# Meta Train Accuracy 0.9612499959766865
# Meta Valid Error 0.2193799990345724
# Meta Valid Accuracy 0.9199999943375587
#
#
# Iteration 675
# Meta Train Error 0.151853329007281
# Meta Train Accuracy 0.9424999952316284
# Meta Valid Error 0.18647717335261405
# Meta Valid Accuracy 0.9299999941140413
#
#
# Iteration 676
# Meta Train Error 0.14055771657149307
# Meta Train Accuracy 0.9462499935179949
# Meta Valid Error 0.19123069191118702
# Meta Valid Accuracy 0.9324999898672104
#
#
# Iteration 677
# Meta Train Error 0.14697194129985292
# Meta Train Accuracy 0.953749991953373
# Meta Valid Error 0.19039917754707858
# Meta Valid Accuracy 0.9325000010430813
#
#
# Iteration 678
# Meta Train Error 0.11403823731234297
# Meta Train Accuracy 0.958749994635582
# Meta Valid Error 0.18610213152715005
# Meta Valid Accuracy 0.9212499987334013
#
#
# Iteration 679
# Meta Train Error 0.09132694930303842
# Meta Train Accuracy 0.9687499962747097
# Meta Valid Error 0.2024803680833429
# Meta Valid Accuracy 0.9224999975413084
#
#
# Iteration 680
# Meta Train Error 0.10342490614857525
# Meta Train Accuracy 0.9649999942630529
# Meta Valid Error 0.23687628144398332
# Meta Valid Accuracy 0.9212499931454659
#
#
# Iteration 681
# Meta Train Error 0.13132010710251052
# Meta Train Accuracy 0.9487499929964542
# Meta Valid Error 0.1529688750160858
# Meta Valid Accuracy 0.9449999965727329
#
#
# Iteration 682
# Meta Train Error 0.12068142784846714
# Meta Train Accuracy 0.9612499922513962
# Meta Valid Error 0.20616083425557008
# Meta Valid Accuracy 0.9299999959766865
#
#
# Iteration 683
# Meta Train Error 0.10716021255939268
# Meta Train Accuracy 0.9599999953061342
# Meta Valid Error 0.16856191522674635
# Meta Valid Accuracy 0.9362499956041574

# %% [markdown]
# ### validation accuracy increases from 29% to 69.4%

# %%
# torch.save(model.state_dict(), 'meta_omniglot2.pth')

# %%
ways=5
shots=1

model=l2l.vision.models.OmniglotFC(28 ** 2, ways)
model.load_state_dict(torch.load('meta_omniglot.pth'))
# model.eval()
# Out:
# OmniglotFC(
#   (features): Sequential(
#     (0): Flatten()
#     (1): Sequential(
#       (0): LinearBlock(
#         (relu): ReLU()
#         (normalize): BatchNorm1d(256, eps=0.001, momentum=0.999, affine=True, track_running_stats=False)
#         (linear): Linear(in_features=784, out_features=256, bias=True)
#       )
#       (1): LinearBlock(
#         (relu): ReLU()
#         (normalize): BatchNorm1d(128, eps=0.001, momentum=0.999, affine=True, track_running_stats=False)
#         (linear): Linear(in_features=256, out_features=128, bias=True)
#       )
#       (2): LinearBlock(
#         (relu): ReLU()
#         (normalize): BatchNorm1d(64, eps=0.001, momentum=0.999, affine=True, track_running_stats=False)
#         (linear): Linear(in_features=128, out_features=64, bias=True)
#       )
#       (3): LinearBlock(
#         (relu): ReLU()
#         (normalize): BatchNorm1d(64, eps=0.001, momentum=0.999, affine=True, track_running_stats=False)
#         (linear): Linear(in_features=64, out_features=64, bias=True)
#       )
#     )
#   )
#   (classifier): Linear(in_features=64, out_features=5, bias=True)
# )
